# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import pandas as pd
data=pd.read_csv('train_covid.csv')

# enc = OneHotEncoder(handle_unknown='ignore')
# enc.fit(data)
data=data[:]
data
# Out:
#            date state_code  gender age_bucket    n   weight_sums  pct_cli  \
# 0      2020/4/6         az  female      35-54  691  7.178188e+05   1.9432
# 1      2020/4/6         fl  female      35-54  594  2.440767e+06   1.1945
# 2      2020/4/6         ia    male        55+   98  3.051519e+05   0.0000
# 3      2020/4/6         in  female      18-34  759  6.789525e+05   1.9920
# 4      2020/4/6         in  female        55+  438  8.263480e+05   0.2309
# ...         ...        ...     ...        ...  ...           ...      ...
# 4995  2020/8/31         tx    male      18-34  202  2.137299e+06   0.5076
# 4996  2020/8/31         wa  female        55+  241  8.556169e+05   0.0000
# 4997  2020/8/31         wa    male      18-34   80  6.770966e+05   0.0000
# 4998  2020/8/31         wa    male        55+  137  8.467731e+05   0.0000
# 4999  2020/8/31         wi    male        55+  120  6.551244e+05   0.0000
#
#       pct_ili  pct_cli_anosmia_ageusia  pct_hh_cli  ...  pct_cancer_weighted  \
# ...

# %%
import matplotlib.pyplot as plt 
# plot a histogram  
data['test_condition'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler
length=data.shape[1]
X=data.iloc[:,0:length-1]
y=data.iloc[:,length-1]
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X, y)

# %%
data_0=X_resampled.loc[y_resampled==0]
data_1=X_resampled.loc[y_resampled==1]
sns.set(style="darkgrid")
for x in ["date","state_code"]:

    y="test_condition"

    sns.histplot(data_0[x],  color="skyblue", label="test_condition=0", kde=True)
    sns.histplot(data_1[x], color="red", label="test_condition=1", kde=True)
    plt.xlabel(x)
    plt.ylabel(y)
    # filename="scatter_plot\histogram_plot(0-5)"+"\{}.png".format(x)
    plt.legend()
    plt.show()
    # plt.savefig(filename)
    # plt.close()

# %%
y_resampled.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
x="date"
y="state_code"
plt.plot( x, y, "", data=data_0, linestyle='', marker='o',color="red")
plt.plot( x, y, "", data=data_1, linestyle='', marker='o')
plt.xlabel(x)
plt.ylabel(y)
plt.title('date&state_code')
plt.show()
# Out:
# C:\Users\Ian\AppData\Local\Temp/ipykernel_17696/3647209215.py:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot( x, y, "", data=data_0, linestyle='', marker='o',color="red")
# C:\Users\Ian\AppData\Local\Temp/ipykernel_17696/3647209215.py:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot( x, y, "", data=data_1, linestyle='', marker='o')
